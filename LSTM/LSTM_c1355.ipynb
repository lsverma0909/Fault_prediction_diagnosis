# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
test_path = '/content/drive/My Drive/circuits/c1355.test'

# %%
import itertools
import random
from collections import defaultdict
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

def expand_dont_care_limited(pattern, max_expand=15):
    x_indices = [i for i, c in enumerate(pattern) if c == 'x']
    if len(x_indices) <= max_expand:
        chars = [(c if c in '01' else ['0', '1']) for c in pattern]
        chars = [(c if isinstance(c, list) else [c]) for c in chars]
        return [''.join(bits) for bits in itertools.product(*chars)]
    else:
        fixed_pattern = list(pattern)
        patterns = []
        for bits in itertools.product('01', repeat=max_expand):
            temp = fixed_pattern.copy()
            for i, bit in zip(x_indices[:max_expand], bits):
                temp[i] = bit
            for i in x_indices[max_expand:]:
                temp[i] = random.choice('01')
            patterns.append(''.join(temp))
        return patterns

def parse_isc_file_limited(filepath, max_expand=3):
    combo_to_fault = {}
    fault_to_idx = {}
    fault_type_map = {}
    idx = 0
    current_fault = None

    with open(filepath, 'r') as file:
        for line in file:
            line = line.strip()
            if not line or line.startswith("*"):
                continue
            if '/' in line:
                parts = line.split("/")
                fault = parts[0].strip().replace("->", "_") + "/" + parts[1].strip()
                if fault not in fault_to_idx:
                    fault_to_idx[fault] = idx
                    if parts[1].strip() == "0":
                        fault_type_map[idx] = "stuck-at-0"
                    elif parts[1].strip() == "1":
                        fault_type_map[idx] = "stuck-at-1"
                    else:
                        fault_type_map[idx] = "unknown"
                    idx += 1
                current_fault = fault
            elif ':' in line and current_fault:
                parts = line.split(":")[1].strip().split()
                input_pat = parts[0]
                output_pat = parts[1] if len(parts) > 1 else ""
                for xi in expand_dont_care_limited(input_pat, max_expand):
                    for yo in expand_dont_care_limited(output_pat, max_expand):
                        combined = xi + yo
                        if combined not in combo_to_fault:
                            combo_to_fault[combined] = fault_to_idx[current_fault]
    return combo_to_fault, fault_to_idx, fault_type_map

# %%
class FaultDatasetMC(Dataset):
    def __init__(self, combo_to_fault):
        self.samples = []
        for combo, label in combo_to_fault.items():
            features = [int(c) for c in combo]
            self.samples.append((features, label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        x, y = self.samples[idx]
        return (
            torch.tensor(x, dtype=torch.float32).unsqueeze(1),  # [seq_len, 1]
            torch.tensor(y, dtype=torch.long)
        )

# %%
class FaultLSTMClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FaultLSTMClassifier, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers=2, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        _, (hn, _) = self.lstm(x)
        return self.fc(hn[-1])  # final hidden state

# %%
combo_to_fault, fault_to_idx, fault_type_map = parse_isc_file_limited(test_path, max_expand=3)
dataset = FaultDatasetMC(combo_to_fault)

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_set, val_set = random_split(dataset, [train_size, val_size], generator=torch.Generator().manual_seed(SEED))

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
val_loader = DataLoader(val_set, batch_size=64)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size = 1
hidden_size = 128
num_classes = len(fault_to_idx)

model = FaultLSTMClassifier(input_size=input_size, hidden_size=hidden_size, num_classes=num_classes).to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
train_losses = []
val_losses = []
val_accuracies = []

for epoch in range(50):
    model.train()
    train_loss = 0.0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(X)
        loss = loss_fn(out, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)

    # Validation
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    type_correct = defaultdict(int)
    type_total = defaultdict(int)

    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            out = model(X)
            loss = loss_fn(out, y)
            val_loss += loss.item()
            preds = out.argmax(dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)

            for pred, label in zip(preds.cpu().numpy(), y.cpu().numpy()):
                ftype = fault_type_map[label]
                type_total[ftype] += 1
                if pred == label:
                    type_correct[ftype] += 1

    val_loss /= len(val_loader)
    accuracy = correct / total
    val_losses.append(val_loss)
    val_accuracies.append(accuracy)

    stuck0_acc = type_correct['stuck-at-0'] / type_total['stuck-at-0'] if type_total['stuck-at-0'] > 0 else 0
    stuck1_acc = type_correct['stuck-at-1'] / type_total['stuck-at-1'] if type_total['stuck-at-1'] > 0 else 0

    print(f"Epoch {epoch:2d} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
          f"Accuracy: {accuracy:.4f} | Stuck-at-0 Acc: {stuck0_acc:.4f} | Stuck-at-1 Acc: {stuck1_acc:.4f}")
# Out:
# Epoch  0 | Train Loss: 5.2238 | Val Loss: 3.8844 | Accuracy: 0.1031 | Stuck-at-0 Acc: 0.0205 | Stuck-at-1 Acc: 0.1203
# Epoch  1 | Train Loss: 3.3941 | Val Loss: 2.9458 | Accuracy: 0.2079 | Stuck-at-0 Acc: 0.1290 | Stuck-at-1 Acc: 0.2242
# Epoch  2 | Train Loss: 2.7686 | Val Loss: 2.5827 | Accuracy: 0.2533 | Stuck-at-0 Acc: 0.2010 | Stuck-at-1 Acc: 0.2641
# Epoch  3 | Train Loss: 2.4458 | Val Loss: 2.3805 | Accuracy: 0.2814 | Stuck-at-0 Acc: 0.1986 | Stuck-at-1 Acc: 0.2985
# Epoch  4 | Train Loss: 2.2457 | Val Loss: 2.1861 | Accuracy: 0.3119 | Stuck-at-0 Acc: 0.2613 | Stuck-at-1 Acc: 0.3224
# Epoch  5 | Train Loss: 2.0910 | Val Loss: 2.0951 | Accuracy: 0.3245 | Stuck-at-0 Acc: 0.2738 | Stuck-at-1 Acc: 0.3350
# Epoch  6 | Train Loss: 1.9769 | Val Loss: 1.9842 | Accuracy: 0.3459 | Stuck-at-0 Acc: 0.2334 | Stuck-at-1 Acc: 0.3693
# Epoch  7 | Train Loss: 1.8795 | Val Loss: 1.9041 | Accuracy: 0.3634 | Stuck-at-0 Acc: 0.2299 | Stuck-at-1 Acc: 0.3912
# Epoch  8 | Train Loss: 1.7970 | Val Loss: 1.8451 | Accuracy: 0.3718 | Stuck-at-0 Acc: 0.2546 | Stuck-at-1 Acc: 0.3961
# Epoch  9 | Train Loss: 1.7610 | Val Loss: 1.7791 | Accuracy: 0.3841 | Stuck-at-0 Acc: 0.2626 | Stuck-at-1 Acc: 0.4094
# Epoch 10 | Train Loss: 1.6616 | Val Loss: 1.7051 | Accuracy: 0.4002 | Stuck-at-0 Acc: 0.2958 | Stuck-at-1 Acc: 0.4219
# Epoch 11 | Train Loss: 1.6210 | Val Loss: 1.6824 | Accuracy: 0.4084 | Stuck-at-0 Acc: 0.2593 | Stuck-at-1 Acc: 0.4393
# Epoch 12 | Train Loss: 1.5580 | Val Loss: 1.6465 | Accuracy: 0.4142 | Stuck-at-0 Acc: 0.3196 | Stuck-at-1 Acc: 0.4338
# Epoch 13 | Train Loss: 1.5094 | Val Loss: 1.5780 | Accuracy: 0.4332 | Stuck-at-0 Acc: 0.2585 | Stuck-at-1 Acc: 0.4694
# Epoch 14 | Train Loss: 1.4699 | Val Loss: 1.5736 | Accuracy: 0.4370 | Stuck-at-0 Acc: 0.2993 | Stuck-at-1 Acc: 0.4656
# Epoch 15 | Train Loss: 1.4378 | Val Loss: 1.5632 | Accuracy: 0.4400 | Stuck-at-0 Acc: 0.3504 | Stuck-at-1 Acc: 0.4586
# Epoch 16 | Train Loss: 1.3819 | Val Loss: 1.5358 | Accuracy: 0.4475 | Stuck-at-0 Acc: 0.3229 | Stuck-at-1 Acc: 0.4734
# Epoch 17 | Train Loss: 1.3515 | Val Loss: 1.4968 | Accuracy: 0.4546 | Stuck-at-0 Acc: 0.2933 | Stuck-at-1 Acc: 0.4881
# Epoch 18 | Train Loss: 1.3066 | Val Loss: 1.4541 | Accuracy: 0.4676 | Stuck-at-0 Acc: 0.3321 | Stuck-at-1 Acc: 0.4958
# Epoch 19 | Train Loss: 1.2797 | Val Loss: 1.4154 | Accuracy: 0.4785 | Stuck-at-0 Acc: 0.3463 | Stuck-at-1 Acc: 0.5060
# Epoch 20 | Train Loss: 1.2430 | Val Loss: 1.3844 | Accuracy: 0.4899 | Stuck-at-0 Acc: 0.3370 | Stuck-at-1 Acc: 0.5216
# Epoch 21 | Train Loss: 1.2038 | Val Loss: 1.3804 | Accuracy: 0.4907 | Stuck-at-0 Acc: 0.3216 | Stuck-at-1 Acc: 0.5258
# Epoch 22 | Train Loss: 1.1817 | Val Loss: 1.3590 | Accuracy: 0.4965 | Stuck-at-0 Acc: 0.3411 | Stuck-at-1 Acc: 0.5288
# Epoch 23 | Train Loss: 1.1596 | Val Loss: 1.3522 | Accuracy: 0.5039 | Stuck-at-0 Acc: 0.3512 | Stuck-at-1 Acc: 0.5356
# Epoch 24 | Train Loss: 1.1196 | Val Loss: 1.2764 | Accuracy: 0.5251 | Stuck-at-0 Acc: 0.3861 | Stuck-at-1 Acc: 0.5540
# Epoch 25 | Train Loss: 1.0917 | Val Loss: 1.2888 | Accuracy: 0.5230 | Stuck-at-0 Acc: 0.3783 | Stuck-at-1 Acc: 0.5531
# Epoch 26 | Train Loss: 1.0694 | Val Loss: 1.2521 | Accuracy: 0.5313 | Stuck-at-0 Acc: 0.3977 | Stuck-at-1 Acc: 0.5591
# Epoch 27 | Train Loss: 1.0459 | Val Loss: 1.2226 | Accuracy: 0.5394 | Stuck-at-0 Acc: 0.4035 | Stuck-at-1 Acc: 0.5677
# Epoch 28 | Train Loss: 1.0113 | Val Loss: 1.1875 | Accuracy: 0.5546 | Stuck-at-0 Acc: 0.4057 | Stuck-at-1 Acc: 0.5856
# Epoch 29 | Train Loss: 0.9905 | Val Loss: 1.1882 | Accuracy: 0.5576 | Stuck-at-0 Acc: 0.3807 | Stuck-at-1 Acc: 0.5943
# Epoch 30 | Train Loss: 0.9725 | Val Loss: 1.1360 | Accuracy: 0.5751 | Stuck-at-0 Acc: 0.4062 | Stuck-at-1 Acc: 0.6101
# Epoch 31 | Train Loss: 0.9539 | Val Loss: 1.1127 | Accuracy: 0.5868 | Stuck-at-0 Acc: 0.4115 | Stuck-at-1 Acc: 0.6232
# Epoch 32 | Train Loss: 0.9279 | Val Loss: 1.0990 | Accuracy: 0.5906 | Stuck-at-0 Acc: 0.4453 | Stuck-at-1 Acc: 0.6208
# Epoch 33 | Train Loss: 0.9096 | Val Loss: 1.1468 | Accuracy: 0.5754 | Stuck-at-0 Acc: 0.4154 | Stuck-at-1 Acc: 0.6087
# Epoch 34 | Train Loss: 0.8932 | Val Loss: 1.0802 | Accuracy: 0.5950 | Stuck-at-0 Acc: 0.3992 | Stuck-at-1 Acc: 0.6356
# Epoch 35 | Train Loss: 0.8818 | Val Loss: 1.0501 | Accuracy: 0.6079 | Stuck-at-0 Acc: 0.4525 | Stuck-at-1 Acc: 0.6402
# Epoch 36 | Train Loss: 0.8778 | Val Loss: 1.0464 | Accuracy: 0.6095 | Stuck-at-0 Acc: 0.4714 | Stuck-at-1 Acc: 0.6382
# Epoch 37 | Train Loss: 0.8373 | Val Loss: 1.0161 | Accuracy: 0.6202 | Stuck-at-0 Acc: 0.4443 | Stuck-at-1 Acc: 0.6567
# Epoch 38 | Train Loss: 0.8261 | Val Loss: 1.0227 | Accuracy: 0.6226 | Stuck-at-0 Acc: 0.4455 | Stuck-at-1 Acc: 0.6594
# Epoch 39 | Train Loss: 0.8217 | Val Loss: 1.0085 | Accuracy: 0.6222 | Stuck-at-0 Acc: 0.4445 | Stuck-at-1 Acc: 0.6591
# Epoch 40 | Train Loss: 0.7972 | Val Loss: 0.9760 | Accuracy: 0.6379 | Stuck-at-0 Acc: 0.4890 | Stuck-at-1 Acc: 0.6688
# Epoch 41 | Train Loss: 0.7859 | Val Loss: 0.9978 | Accuracy: 0.6343 | Stuck-at-0 Acc: 0.4706 | Stuck-at-1 Acc: 0.6683
# Epoch 42 | Train Loss: 0.7693 | Val Loss: 0.9936 | Accuracy: 0.6327 | Stuck-at-0 Acc: 0.4864 | Stuck-at-1 Acc: 0.6630
# Epoch 43 | Train Loss: 0.7684 | Val Loss: 0.9436 | Accuracy: 0.6535 | Stuck-at-0 Acc: 0.5100 | Stuck-at-1 Acc: 0.6834
# Epoch 44 | Train Loss: 0.7706 | Val Loss: 0.9662 | Accuracy: 0.6458 | Stuck-at-0 Acc: 0.4782 | Stuck-at-1 Acc: 0.6806
# Epoch 45 | Train Loss: 0.7332 | Val Loss: 0.9437 | Accuracy: 0.6554 | Stuck-at-0 Acc: 0.4958 | Stuck-at-1 Acc: 0.6886
# Epoch 46 | Train Loss: 0.7201 | Val Loss: 0.9343 | Accuracy: 0.6565 | Stuck-at-0 Acc: 0.4966 | Stuck-at-1 Acc: 0.6897
# Epoch 47 | Train Loss: 0.7183 | Val Loss: 0.9216 | Accuracy: 0.6648 | Stuck-at-0 Acc: 0.4948 | Stuck-at-1 Acc: 0.7000
# Epoch 48 | Train Loss: 0.6994 | Val Loss: 0.8820 | Accuracy: 0.6793 | Stuck-at-0 Acc: 0.4976 | Stuck-at-1 Acc: 0.7170
# Epoch 49 | Train Loss: 0.6943 | Val Loss: 0.8828 | Accuracy: 0.6783 | Stuck-at-0 Acc: 0.5180 | Stuck-at-1 Acc: 0.7116

# %%
final_accuracy = val_accuracies[-1]

print(f"\n--- Final Overall Validation Accuracy ---")
print(f"Total Accuracy = {final_accuracy:.4f} ({correct}/{total})")

print("\n--- Final Fault-Type Accuracy ---")
for ftype in sorted(type_total):
    acc = type_correct[ftype] / type_total[ftype]
    print(f"{ftype}: Accuracy = {acc:.4f} ({type_correct[ftype]}/{type_total[ftype]})")
# Out:
# --- Final Overall Validation Accuracy ---
# Total Accuracy = 0.6783 (20212/29799)
#
# --- Final Fault-Type Accuracy ---
# stuck-at-0: Accuracy = 0.5180 (2655/5125)
# stuck-at-1: Accuracy = 0.7116 (17557/24674)

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(12, 5))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.plot(epochs, val_losses, label='Val Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()
plt.grid(True)

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, val_accuracies, label='Val Accuracy', color='green', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy Over Epochs')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
