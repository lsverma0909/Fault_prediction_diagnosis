# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
test_path = '/content/drive/My Drive/circuits/c499.test'

# %%
import itertools
import random
from collections import defaultdict
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

SEED = 84
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

def expand_dont_care_limited(pattern, max_expand=15):
    x_indices = [i for i, c in enumerate(pattern) if c == 'x']
    if len(x_indices) <= max_expand:
        chars = [(c if c in '01' else ['0', '1']) for c in pattern]
        chars = [(c if isinstance(c, list) else [c]) for c in chars]
        return [''.join(bits) for bits in itertools.product(*chars)]
    else:
        fixed_pattern = list(pattern)
        patterns = []
        for bits in itertools.product('01', repeat=max_expand):
            temp = fixed_pattern.copy()
            for i, bit in zip(x_indices[:max_expand], bits):
                temp[i] = bit
            for i in x_indices[max_expand:]:
                temp[i] = random.choice('01')
            patterns.append(''.join(temp))
        return patterns

def parse_isc_file_limited(filepath, max_expand=3):
    combo_to_fault = {}
    fault_to_idx = {}
    fault_type_map = {}
    idx = 0
    current_fault = None

    with open(filepath, 'r') as file:
        for line in file:
            line = line.strip()
            if not line or line.startswith("*"):
                continue
            if '/' in line:
                parts = line.split("/")
                fault = parts[0].strip().replace("->", "_") + "/" + parts[1].strip()
                if fault not in fault_to_idx:
                    fault_to_idx[fault] = idx
                    if parts[1].strip() == "0":
                        fault_type_map[idx] = "stuck-at-0"
                    elif parts[1].strip() == "1":
                        fault_type_map[idx] = "stuck-at-1"
                    else:
                        fault_type_map[idx] = "unknown"
                    idx += 1
                current_fault = fault
            elif ':' in line and current_fault:
                parts = line.split(":")[1].strip().split()
                input_pat = parts[0]
                output_pat = parts[1] if len(parts) > 1 else ""
                for xi in expand_dont_care_limited(input_pat, max_expand):
                    for yo in expand_dont_care_limited(output_pat, max_expand):
                        combined = xi + yo
                        if combined not in combo_to_fault:
                            combo_to_fault[combined] = fault_to_idx[current_fault]
    return combo_to_fault, fault_to_idx, fault_type_map

# %%
class FaultDatasetMC(Dataset):
    def __init__(self, combo_to_fault):
        self.samples = []
        for combo, label in combo_to_fault.items():
            features = [int(c) for c in combo]
            self.samples.append((features, label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        x, y = self.samples[idx]
        return (
            torch.tensor(x, dtype=torch.float32).unsqueeze(1),  # [seq_len, 1]
            torch.tensor(y, dtype=torch.long)
        )

# %%
class FaultLSTMClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FaultLSTMClassifier, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers=2, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        _, (hn, _) = self.lstm(x)
        return self.fc(hn[-1])  # final hidden state

# %%
combo_to_fault, fault_to_idx, fault_type_map = parse_isc_file_limited(test_path, max_expand=3)
dataset = FaultDatasetMC(combo_to_fault)

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_set, val_set = random_split(dataset, [train_size, val_size], generator=torch.Generator().manual_seed(SEED))

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
val_loader = DataLoader(val_set, batch_size=64)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size = 1
hidden_size = 128
num_classes = len(fault_to_idx)

model = FaultLSTMClassifier(input_size=input_size, hidden_size=hidden_size, num_classes=num_classes).to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
train_losses = []
val_losses = []
val_accuracies = []

for epoch in range(50):
    model.train()
    train_loss = 0.0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(X)
        loss = loss_fn(out, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)

    # Validation
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    type_correct = defaultdict(int)
    type_total = defaultdict(int)

    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            out = model(X)
            loss = loss_fn(out, y)
            val_loss += loss.item()
            preds = out.argmax(dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)

            for pred, label in zip(preds.cpu().numpy(), y.cpu().numpy()):
                ftype = fault_type_map[label]
                type_total[ftype] += 1
                if pred == label:
                    type_correct[ftype] += 1

    val_loss /= len(val_loader)
    accuracy = correct / total
    val_losses.append(val_loss)
    val_accuracies.append(accuracy)

    stuck0_acc = type_correct['stuck-at-0'] / type_total['stuck-at-0'] if type_total['stuck-at-0'] > 0 else 0
    stuck1_acc = type_correct['stuck-at-1'] / type_total['stuck-at-1'] if type_total['stuck-at-1'] > 0 else 0

    print(f"Epoch {epoch:2d} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
          f"Accuracy: {accuracy:.4f} | Stuck-at-0 Acc: {stuck0_acc:.4f} | Stuck-at-1 Acc: {stuck1_acc:.4f}")
# Out:
# Epoch  0 | Train Loss: 5.6196 | Val Loss: 4.6288 | Accuracy: 0.1048 | Stuck-at-0 Acc: 0.1727 | Stuck-at-1 Acc: 0.0517
# Epoch  1 | Train Loss: 4.0880 | Val Loss: 3.3352 | Accuracy: 0.3137 | Stuck-at-0 Acc: 0.4145 | Stuck-at-1 Acc: 0.2347
# Epoch  2 | Train Loss: 2.8265 | Val Loss: 2.4978 | Accuracy: 0.4539 | Stuck-at-0 Acc: 0.5656 | Stuck-at-1 Acc: 0.3665
# Epoch  3 | Train Loss: 2.4019 | Val Loss: 2.1690 | Accuracy: 0.5012 | Stuck-at-0 Acc: 0.6150 | Stuck-at-1 Acc: 0.4122
# Epoch  4 | Train Loss: 1.9464 | Val Loss: 1.8381 | Accuracy: 0.5543 | Stuck-at-0 Acc: 0.6794 | Stuck-at-1 Acc: 0.4564
# Epoch  5 | Train Loss: 1.6945 | Val Loss: 1.6364 | Accuracy: 0.5859 | Stuck-at-0 Acc: 0.7062 | Stuck-at-1 Acc: 0.4917
# Epoch  6 | Train Loss: 1.5508 | Val Loss: 1.5152 | Accuracy: 0.6040 | Stuck-at-0 Acc: 0.7287 | Stuck-at-1 Acc: 0.5064
# Epoch  7 | Train Loss: 1.3802 | Val Loss: 1.4019 | Accuracy: 0.6256 | Stuck-at-0 Acc: 0.7503 | Stuck-at-1 Acc: 0.5281
# Epoch  8 | Train Loss: 1.2601 | Val Loss: 1.3123 | Accuracy: 0.6458 | Stuck-at-0 Acc: 0.7671 | Stuck-at-1 Acc: 0.5509
# Epoch  9 | Train Loss: 1.1728 | Val Loss: 1.3496 | Accuracy: 0.6351 | Stuck-at-0 Acc: 0.7538 | Stuck-at-1 Acc: 0.5423
# Epoch 10 | Train Loss: 1.0902 | Val Loss: 1.1904 | Accuracy: 0.6729 | Stuck-at-0 Acc: 0.7854 | Stuck-at-1 Acc: 0.5848
# Epoch 11 | Train Loss: 1.0471 | Val Loss: 1.1943 | Accuracy: 0.6676 | Stuck-at-0 Acc: 0.7820 | Stuck-at-1 Acc: 0.5780
# Epoch 12 | Train Loss: 0.9636 | Val Loss: 1.0918 | Accuracy: 0.6900 | Stuck-at-0 Acc: 0.7945 | Stuck-at-1 Acc: 0.6082
# Epoch 13 | Train Loss: 0.9056 | Val Loss: 1.0134 | Accuracy: 0.7076 | Stuck-at-0 Acc: 0.8126 | Stuck-at-1 Acc: 0.6254
# Epoch 14 | Train Loss: 0.8440 | Val Loss: 0.9825 | Accuracy: 0.7145 | Stuck-at-0 Acc: 0.8192 | Stuck-at-1 Acc: 0.6325
# Epoch 15 | Train Loss: 0.8026 | Val Loss: 0.9688 | Accuracy: 0.7174 | Stuck-at-0 Acc: 0.8168 | Stuck-at-1 Acc: 0.6395
# Epoch 16 | Train Loss: 0.7671 | Val Loss: 0.9081 | Accuracy: 0.7296 | Stuck-at-0 Acc: 0.8319 | Stuck-at-1 Acc: 0.6495
# Epoch 17 | Train Loss: 0.7264 | Val Loss: 0.9124 | Accuracy: 0.7330 | Stuck-at-0 Acc: 0.8281 | Stuck-at-1 Acc: 0.6586
# Epoch 18 | Train Loss: 0.6873 | Val Loss: 0.8564 | Accuracy: 0.7437 | Stuck-at-0 Acc: 0.8348 | Stuck-at-1 Acc: 0.6723
# Epoch 19 | Train Loss: 0.6492 | Val Loss: 0.8225 | Accuracy: 0.7525 | Stuck-at-0 Acc: 0.8397 | Stuck-at-1 Acc: 0.6842
# Epoch 20 | Train Loss: 0.6241 | Val Loss: 0.8201 | Accuracy: 0.7533 | Stuck-at-0 Acc: 0.8428 | Stuck-at-1 Acc: 0.6832
# Epoch 21 | Train Loss: 0.5925 | Val Loss: 0.8003 | Accuracy: 0.7608 | Stuck-at-0 Acc: 0.8551 | Stuck-at-1 Acc: 0.6869
# Epoch 22 | Train Loss: 0.5649 | Val Loss: 0.7638 | Accuracy: 0.7698 | Stuck-at-0 Acc: 0.8554 | Stuck-at-1 Acc: 0.7028
# Epoch 23 | Train Loss: 0.5364 | Val Loss: 0.7568 | Accuracy: 0.7722 | Stuck-at-0 Acc: 0.8587 | Stuck-at-1 Acc: 0.7045
# Epoch 24 | Train Loss: 0.5195 | Val Loss: 0.7160 | Accuracy: 0.7834 | Stuck-at-0 Acc: 0.8673 | Stuck-at-1 Acc: 0.7177
# Epoch 25 | Train Loss: 0.4900 | Val Loss: 0.7236 | Accuracy: 0.7826 | Stuck-at-0 Acc: 0.8629 | Stuck-at-1 Acc: 0.7197
# Epoch 26 | Train Loss: 0.4791 | Val Loss: 0.6730 | Accuracy: 0.7957 | Stuck-at-0 Acc: 0.8686 | Stuck-at-1 Acc: 0.7387
# Epoch 27 | Train Loss: 0.4551 | Val Loss: 0.7053 | Accuracy: 0.7833 | Stuck-at-0 Acc: 0.8599 | Stuck-at-1 Acc: 0.7234
# Epoch 28 | Train Loss: 0.4356 | Val Loss: 0.6449 | Accuracy: 0.8019 | Stuck-at-0 Acc: 0.8723 | Stuck-at-1 Acc: 0.7468
# Epoch 29 | Train Loss: 0.4122 | Val Loss: 0.6246 | Accuracy: 0.8092 | Stuck-at-0 Acc: 0.8803 | Stuck-at-1 Acc: 0.7536
# Epoch 30 | Train Loss: 0.3961 | Val Loss: 0.6250 | Accuracy: 0.8128 | Stuck-at-0 Acc: 0.8766 | Stuck-at-1 Acc: 0.7629
# Epoch 31 | Train Loss: 0.3822 | Val Loss: 0.6241 | Accuracy: 0.8138 | Stuck-at-0 Acc: 0.8874 | Stuck-at-1 Acc: 0.7562
# Epoch 32 | Train Loss: 0.3680 | Val Loss: 0.5963 | Accuracy: 0.8183 | Stuck-at-0 Acc: 0.8904 | Stuck-at-1 Acc: 0.7618
# Epoch 33 | Train Loss: 0.3632 | Val Loss: 0.5949 | Accuracy: 0.8150 | Stuck-at-0 Acc: 0.8839 | Stuck-at-1 Acc: 0.7611
# Epoch 34 | Train Loss: 0.3366 | Val Loss: 0.5770 | Accuracy: 0.8258 | Stuck-at-0 Acc: 0.8847 | Stuck-at-1 Acc: 0.7796
# Epoch 35 | Train Loss: 0.3354 | Val Loss: 0.5715 | Accuracy: 0.8229 | Stuck-at-0 Acc: 0.8905 | Stuck-at-1 Acc: 0.7699
# Epoch 36 | Train Loss: 0.3244 | Val Loss: 0.5531 | Accuracy: 0.8326 | Stuck-at-0 Acc: 0.8935 | Stuck-at-1 Acc: 0.7849
# Epoch 37 | Train Loss: 0.3048 | Val Loss: 0.6082 | Accuracy: 0.8179 | Stuck-at-0 Acc: 0.8913 | Stuck-at-1 Acc: 0.7603
# Epoch 38 | Train Loss: 0.3207 | Val Loss: 0.5787 | Accuracy: 0.8243 | Stuck-at-0 Acc: 0.8874 | Stuck-at-1 Acc: 0.7748
# Epoch 39 | Train Loss: 0.2853 | Val Loss: 0.5626 | Accuracy: 0.8300 | Stuck-at-0 Acc: 0.8830 | Stuck-at-1 Acc: 0.7885
# Epoch 40 | Train Loss: 0.2826 | Val Loss: 0.5388 | Accuracy: 0.8362 | Stuck-at-0 Acc: 0.8979 | Stuck-at-1 Acc: 0.7880
# Epoch 41 | Train Loss: 0.2654 | Val Loss: 0.5358 | Accuracy: 0.8400 | Stuck-at-0 Acc: 0.8927 | Stuck-at-1 Acc: 0.7988
# Epoch 42 | Train Loss: 0.2700 | Val Loss: 0.5057 | Accuracy: 0.8484 | Stuck-at-0 Acc: 0.9021 | Stuck-at-1 Acc: 0.8063
# Epoch 43 | Train Loss: 0.2599 | Val Loss: 0.5190 | Accuracy: 0.8457 | Stuck-at-0 Acc: 0.9015 | Stuck-at-1 Acc: 0.8020
# Epoch 44 | Train Loss: 0.2614 | Val Loss: 0.5090 | Accuracy: 0.8486 | Stuck-at-0 Acc: 0.9059 | Stuck-at-1 Acc: 0.8037
# Epoch 45 | Train Loss: 0.2477 | Val Loss: 0.5198 | Accuracy: 0.8448 | Stuck-at-0 Acc: 0.8976 | Stuck-at-1 Acc: 0.8034
# Epoch 46 | Train Loss: 0.2365 | Val Loss: 0.4840 | Accuracy: 0.8542 | Stuck-at-0 Acc: 0.9029 | Stuck-at-1 Acc: 0.8161
# Epoch 47 | Train Loss: 0.2325 | Val Loss: 0.4872 | Accuracy: 0.8588 | Stuck-at-0 Acc: 0.9046 | Stuck-at-1 Acc: 0.8228
# Epoch 48 | Train Loss: 0.2332 | Val Loss: 0.5545 | Accuracy: 0.8371 | Stuck-at-0 Acc: 0.8962 | Stuck-at-1 Acc: 0.7908
# Epoch 49 | Train Loss: 0.2220 | Val Loss: 0.4986 | Accuracy: 0.8522 | Stuck-at-0 Acc: 0.9032 | Stuck-at-1 Acc: 0.8123

# %%
final_accuracy = val_accuracies[-1]

print(f"\n--- Final Overall Validation Accuracy ---")
print(f"Total Accuracy = {final_accuracy:.4f} ({correct}/{total})")

print("\n--- Final Fault-Type Accuracy ---")
for ftype in sorted(type_total):
    acc = type_correct[ftype] / type_total[ftype]
    print(f"{ftype}: Accuracy = {acc:.4f} ({type_correct[ftype]}/{type_total[ftype]})")
# Out:
# --- Final Overall Validation Accuracy ---
# Total Accuracy = 0.8522 (12375/14521)
#
# --- Final Fault-Type Accuracy ---
# stuck-at-0: Accuracy = 0.9032 (5759/6376)
# stuck-at-1: Accuracy = 0.8123 (6616/8145)

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(12, 5))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.plot(epochs, val_losses, label='Val Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()
plt.grid(True)

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, val_accuracies, label='Val Accuracy', color='green', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy Over Epochs')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
