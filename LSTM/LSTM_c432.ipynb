# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_path = '/content/drive/My Drive/circuits/c432.test'

# %%
import itertools
import random
from collections import defaultdict
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

def expand_dont_care_limited(pattern, max_expand=15):
    x_indices = [i for i, c in enumerate(pattern) if c == 'x']
    if len(x_indices) <= max_expand:
        chars = [(c if c in '01' else ['0', '1']) for c in pattern]
        chars = [(c if isinstance(c, list) else [c]) for c in chars]
        return [''.join(bits) for bits in itertools.product(*chars)]
    else:
        fixed_pattern = list(pattern)
        patterns = []
        for bits in itertools.product('01', repeat=max_expand):
            temp = fixed_pattern.copy()
            for i, bit in zip(x_indices[:max_expand], bits):
                temp[i] = bit
            for i in x_indices[max_expand:]:
                temp[i] = random.choice('01')
            patterns.append(''.join(temp))
        return patterns

def parse_isc_file_limited(filepath, max_expand=3):
    combo_to_fault = {}
    fault_to_idx = {}
    fault_type_map = {}
    idx = 0
    current_fault = None

    with open(filepath, 'r') as file:
        for line in file:
            line = line.strip()
            if not line or line.startswith("*"):
                continue
            if '/' in line:
                parts = line.split("/")
                fault = parts[0].strip().replace("->", "_") + "/" + parts[1].strip()
                if fault not in fault_to_idx:
                    fault_to_idx[fault] = idx
                    if parts[1].strip() == "0":
                        fault_type_map[idx] = "stuck-at-0"
                    elif parts[1].strip() == "1":
                        fault_type_map[idx] = "stuck-at-1"
                    else:
                        fault_type_map[idx] = "unknown"
                    idx += 1
                current_fault = fault
            elif ':' in line and current_fault:
                parts = line.split(":")[1].strip().split()
                input_pat = parts[0]
                output_pat = parts[1] if len(parts) > 1 else ""
                for xi in expand_dont_care_limited(input_pat, max_expand):
                    for yo in expand_dont_care_limited(output_pat, max_expand):
                        combined = xi + yo
                        if combined not in combo_to_fault:
                            combo_to_fault[combined] = fault_to_idx[current_fault]
    return combo_to_fault, fault_to_idx, fault_type_map

# %%
class FaultDatasetMC(Dataset):
    def __init__(self, combo_to_fault):
        self.samples = []
        for combo, label in combo_to_fault.items():
            features = [int(c) for c in combo]
            self.samples.append((features, label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        x, y = self.samples[idx]
        return (
            torch.tensor(x, dtype=torch.float32).unsqueeze(1),  # [seq_len, 1]
            torch.tensor(y, dtype=torch.long)
        )

# %%
class FaultLSTMClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FaultLSTMClassifier, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers=2, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        _, (hn, _) = self.lstm(x)
        return self.fc(hn[-1])  # final hidden state

# %%
combo_to_fault, fault_to_idx, fault_type_map = parse_isc_file_limited(test_path, max_expand=3)
dataset = FaultDatasetMC(combo_to_fault)

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_set, val_set = random_split(dataset, [train_size, val_size], generator=torch.Generator().manual_seed(SEED))

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
val_loader = DataLoader(val_set, batch_size=64)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size = 1
hidden_size = 128
num_classes = len(fault_to_idx)

model = FaultLSTMClassifier(input_size=input_size, hidden_size=hidden_size, num_classes=num_classes).to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
train_losses = []
val_losses = []
val_accuracies = []

for epoch in range(50):
    model.train()
    train_loss = 0.0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(X)
        loss = loss_fn(out, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)

    # Validation
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    type_correct = defaultdict(int)
    type_total = defaultdict(int)

    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            out = model(X)
            loss = loss_fn(out, y)
            val_loss += loss.item()
            preds = out.argmax(dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)

            for pred, label in zip(preds.cpu().numpy(), y.cpu().numpy()):
                ftype = fault_type_map[label]
                type_total[ftype] += 1
                if pred == label:
                    type_correct[ftype] += 1

    val_loss /= len(val_loader)
    accuracy = correct / total
    val_losses.append(val_loss)
    val_accuracies.append(accuracy)

    stuck0_acc = type_correct['stuck-at-0'] / type_total['stuck-at-0'] if type_total['stuck-at-0'] > 0 else 0
    stuck1_acc = type_correct['stuck-at-1'] / type_total['stuck-at-1'] if type_total['stuck-at-1'] > 0 else 0

    print(f"Epoch {epoch:2d} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
          f"Accuracy: {accuracy:.4f} | Stuck-at-0 Acc: {stuck0_acc:.4f} | Stuck-at-1 Acc: {stuck1_acc:.4f}")
# Out:
# Epoch  0 | Train Loss: 5.9761 | Val Loss: 5.9336 | Accuracy: 0.0039 | Stuck-at-0 Acc: 0.0000 | Stuck-at-1 Acc: 0.0058
# Epoch  1 | Train Loss: 5.9309 | Val Loss: 5.9116 | Accuracy: 0.0062 | Stuck-at-0 Acc: 0.0132 | Stuck-at-1 Acc: 0.0029
# Epoch  2 | Train Loss: 5.2913 | Val Loss: 4.7670 | Accuracy: 0.0418 | Stuck-at-0 Acc: 0.0289 | Stuck-at-1 Acc: 0.0479
# Epoch  3 | Train Loss: 4.4072 | Val Loss: 4.1615 | Accuracy: 0.0820 | Stuck-at-0 Acc: 0.0909 | Stuck-at-1 Acc: 0.0778
# Epoch  4 | Train Loss: 3.7944 | Val Loss: 3.6262 | Accuracy: 0.1363 | Stuck-at-0 Acc: 0.1331 | Stuck-at-1 Acc: 0.1379
# Epoch  5 | Train Loss: 3.2965 | Val Loss: 3.2291 | Accuracy: 0.1981 | Stuck-at-0 Acc: 0.2235 | Stuck-at-1 Acc: 0.1860
# Epoch  6 | Train Loss: 2.8814 | Val Loss: 2.8378 | Accuracy: 0.2657 | Stuck-at-0 Acc: 0.2839 | Stuck-at-1 Acc: 0.2570
# Epoch  7 | Train Loss: 2.5369 | Val Loss: 2.5208 | Accuracy: 0.3221 | Stuck-at-0 Acc: 0.3677 | Stuck-at-1 Acc: 0.3003
# Epoch  8 | Train Loss: 2.2371 | Val Loss: 2.3223 | Accuracy: 0.3611 | Stuck-at-0 Acc: 0.3936 | Stuck-at-1 Acc: 0.3455
# Epoch  9 | Train Loss: 1.9703 | Val Loss: 2.0389 | Accuracy: 0.4281 | Stuck-at-0 Acc: 0.4266 | Stuck-at-1 Acc: 0.4289
# Epoch 10 | Train Loss: 1.7455 | Val Loss: 1.8492 | Accuracy: 0.4744 | Stuck-at-0 Acc: 0.4769 | Stuck-at-1 Acc: 0.4731
# Epoch 11 | Train Loss: 1.5624 | Val Loss: 1.7005 | Accuracy: 0.5158 | Stuck-at-0 Acc: 0.5165 | Stuck-at-1 Acc: 0.5154
# Epoch 12 | Train Loss: 1.3840 | Val Loss: 1.5571 | Accuracy: 0.5597 | Stuck-at-0 Acc: 0.5876 | Stuck-at-1 Acc: 0.5463
# Epoch 13 | Train Loss: 1.2418 | Val Loss: 1.4199 | Accuracy: 0.6061 | Stuck-at-0 Acc: 0.6140 | Stuck-at-1 Acc: 0.6022
# Epoch 14 | Train Loss: 1.1201 | Val Loss: 1.3433 | Accuracy: 0.6166 | Stuck-at-0 Acc: 0.6262 | Stuck-at-1 Acc: 0.6120
# Epoch 15 | Train Loss: 1.0002 | Val Loss: 1.2156 | Accuracy: 0.6628 | Stuck-at-0 Acc: 0.6760 | Stuck-at-1 Acc: 0.6565
# Epoch 16 | Train Loss: 0.9081 | Val Loss: 1.1470 | Accuracy: 0.6827 | Stuck-at-0 Acc: 0.6897 | Stuck-at-1 Acc: 0.6793
# Epoch 17 | Train Loss: 0.8069 | Val Loss: 1.0182 | Accuracy: 0.7257 | Stuck-at-0 Acc: 0.7410 | Stuck-at-1 Acc: 0.7185
# Epoch 18 | Train Loss: 0.7290 | Val Loss: 1.0113 | Accuracy: 0.7190 | Stuck-at-0 Acc: 0.7405 | Stuck-at-1 Acc: 0.7087
# Epoch 19 | Train Loss: 0.6601 | Val Loss: 0.9401 | Accuracy: 0.7366 | Stuck-at-0 Acc: 0.7608 | Stuck-at-1 Acc: 0.7250
# Epoch 20 | Train Loss: 0.6072 | Val Loss: 0.8428 | Accuracy: 0.7759 | Stuck-at-0 Acc: 0.7963 | Stuck-at-1 Acc: 0.7661
# Epoch 21 | Train Loss: 0.5571 | Val Loss: 0.8492 | Accuracy: 0.7654 | Stuck-at-0 Acc: 0.7816 | Stuck-at-1 Acc: 0.7576
# Epoch 22 | Train Loss: 0.5119 | Val Loss: 0.7720 | Accuracy: 0.7960 | Stuck-at-0 Acc: 0.8177 | Stuck-at-1 Acc: 0.7856
# Epoch 23 | Train Loss: 0.5203 | Val Loss: 0.7517 | Accuracy: 0.7948 | Stuck-at-0 Acc: 0.8121 | Stuck-at-1 Acc: 0.7865
# Epoch 24 | Train Loss: 0.4276 | Val Loss: 0.6909 | Accuracy: 0.8209 | Stuck-at-0 Acc: 0.8380 | Stuck-at-1 Acc: 0.8128
# Epoch 25 | Train Loss: 0.4043 | Val Loss: 0.6592 | Accuracy: 0.8229 | Stuck-at-0 Acc: 0.8405 | Stuck-at-1 Acc: 0.8145
# Epoch 26 | Train Loss: 0.3607 | Val Loss: 0.6392 | Accuracy: 0.8300 | Stuck-at-0 Acc: 0.8487 | Stuck-at-1 Acc: 0.8211
# Epoch 27 | Train Loss: 0.3470 | Val Loss: 0.6533 | Accuracy: 0.8244 | Stuck-at-0 Acc: 0.8370 | Stuck-at-1 Acc: 0.8184
# Epoch 28 | Train Loss: 0.3739 | Val Loss: 0.6403 | Accuracy: 0.8323 | Stuck-at-0 Acc: 0.8547 | Stuck-at-1 Acc: 0.8215
# Epoch 29 | Train Loss: 0.3004 | Val Loss: 0.5923 | Accuracy: 0.8392 | Stuck-at-0 Acc: 0.8512 | Stuck-at-1 Acc: 0.8335
# Epoch 30 | Train Loss: 0.2967 | Val Loss: 0.5858 | Accuracy: 0.8476 | Stuck-at-0 Acc: 0.8690 | Stuck-at-1 Acc: 0.8373
# Epoch 31 | Train Loss: 0.3192 | Val Loss: 0.6418 | Accuracy: 0.8269 | Stuck-at-0 Acc: 0.8471 | Stuck-at-1 Acc: 0.8172
# Epoch 32 | Train Loss: 0.2808 | Val Loss: 0.5419 | Accuracy: 0.8548 | Stuck-at-0 Acc: 0.8730 | Stuck-at-1 Acc: 0.8461
# Epoch 33 | Train Loss: 0.2416 | Val Loss: 0.5630 | Accuracy: 0.8500 | Stuck-at-0 Acc: 0.8695 | Stuck-at-1 Acc: 0.8407
# Epoch 34 | Train Loss: 0.2578 | Val Loss: 0.5797 | Accuracy: 0.8451 | Stuck-at-0 Acc: 0.8664 | Stuck-at-1 Acc: 0.8349
# Epoch 35 | Train Loss: 0.2254 | Val Loss: 0.5144 | Accuracy: 0.8657 | Stuck-at-0 Acc: 0.8791 | Stuck-at-1 Acc: 0.8592
# Epoch 36 | Train Loss: 0.2291 | Val Loss: 1.1684 | Accuracy: 0.7059 | Stuck-at-0 Acc: 0.7120 | Stuck-at-1 Acc: 0.7029
# Epoch 37 | Train Loss: 0.2807 | Val Loss: 0.5245 | Accuracy: 0.8609 | Stuck-at-0 Acc: 0.8857 | Stuck-at-1 Acc: 0.8490
# Epoch 38 | Train Loss: 0.2054 | Val Loss: 0.5137 | Accuracy: 0.8695 | Stuck-at-0 Acc: 0.8842 | Stuck-at-1 Acc: 0.8624
# Epoch 39 | Train Loss: 0.1784 | Val Loss: 0.5293 | Accuracy: 0.8602 | Stuck-at-0 Acc: 0.8807 | Stuck-at-1 Acc: 0.8505
# Epoch 40 | Train Loss: 0.1864 | Val Loss: 0.5147 | Accuracy: 0.8658 | Stuck-at-0 Acc: 0.8781 | Stuck-at-1 Acc: 0.8600
# Epoch 41 | Train Loss: 0.2246 | Val Loss: 0.5526 | Accuracy: 0.8566 | Stuck-at-0 Acc: 0.8690 | Stuck-at-1 Acc: 0.8507
# Epoch 42 | Train Loss: 0.1823 | Val Loss: 0.5214 | Accuracy: 0.8662 | Stuck-at-0 Acc: 0.8781 | Stuck-at-1 Acc: 0.8604
# Epoch 43 | Train Loss: 0.1608 | Val Loss: 0.5870 | Accuracy: 0.8482 | Stuck-at-0 Acc: 0.8629 | Stuck-at-1 Acc: 0.8412
# Epoch 44 | Train Loss: 0.2501 | Val Loss: 0.4945 | Accuracy: 0.8726 | Stuck-at-0 Acc: 0.8812 | Stuck-at-1 Acc: 0.8685
# Epoch 45 | Train Loss: 0.1963 | Val Loss: 0.4825 | Accuracy: 0.8816 | Stuck-at-0 Acc: 0.8928 | Stuck-at-1 Acc: 0.8762
# Epoch 46 | Train Loss: 0.1281 | Val Loss: 0.4821 | Accuracy: 0.8862 | Stuck-at-0 Acc: 0.8989 | Stuck-at-1 Acc: 0.8801
# Epoch 47 | Train Loss: 0.1363 | Val Loss: 0.5130 | Accuracy: 0.8741 | Stuck-at-0 Acc: 0.8822 | Stuck-at-1 Acc: 0.8702
# Epoch 48 | Train Loss: 0.1511 | Val Loss: 0.5084 | Accuracy: 0.8745 | Stuck-at-0 Acc: 0.8801 | Stuck-at-1 Acc: 0.8719
# Epoch 49 | Train Loss: 0.2381 | Val Loss: 0.5297 | Accuracy: 0.8634 | Stuck-at-0 Acc: 0.8700 | Stuck-at-1 Acc: 0.8602

# %%
final_accuracy = val_accuracies[-1]

print(f"\n--- Final Overall Validation Accuracy ---")
print(f"Total Accuracy = {final_accuracy:.4f} ({correct}/{total})")

print("\n--- Final Fault-Type Accuracy ---")
for ftype in sorted(type_total):
    acc = type_correct[ftype] / type_total[ftype]
    print(f"{ftype}: Accuracy = {acc:.4f} ({type_correct[ftype]}/{type_total[ftype]})")
# Out:
# --- Final Overall Validation Accuracy ---
# Total Accuracy = 0.8634 (5251/6082)
#
# --- Final Fault-Type Accuracy ---
# stuck-at-0: Accuracy = 0.8700 (1713/1969)
# stuck-at-1: Accuracy = 0.8602 (3538/4113)

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(12, 5))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.plot(epochs, val_losses, label='Val Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()
plt.grid(True)

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, val_accuracies, label='Val Accuracy', color='green', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy Over Epochs')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
